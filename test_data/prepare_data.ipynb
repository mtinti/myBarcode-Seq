# %%
# !pwd
# Out:
# /app/host_mnt/Users/mtinti/git_projects/myBarcode-Seq/test_data

# %%
#../results/TbRIT-8166/TbRIT-8166.sorted_dedup.bam

# %%
#!samtools view -b results/TbRIT-8166/TbRIT-8166.sorted_dedup.bam "Tb927_08_v5.1:272330-285554" > test_data/test_oe/test_region.bam
#shuld have taken picard extension from data, flagged but not deduplicate. no problem for the test
# Out:
# /usr/bin/sh: 1: cannot create ../test_data/test_oe/test_region.bam: Directory nonexistent

# %%
#samtools view -b results/TbRIT-8166/TbRIT-8166.sorted_dedup.bam "Tb927_08_v5.1:272330-285554" > test_data/test_oe/test_region.bam

# %%
#!snakemake --use-conda --cores 8 --configfile test_data/test_rit/config_test.yaml

# %%
#Tb927.8.910	Tb927_08_v5.1	272330	285554	-	13225	2518706	2155872	362834	2518706
# sampled
#Tb927.8.910	Tb927_08_v5.1	272330	285554	-	13225	25096	21496	3600	28762

# %%
#!samtools view -b ../data/TbOE8166H/TbOE8166H.picard.bam Tb927_10_v5.1:1640000-1650000 > ../test_data/test_oe/test_region.bam

# %%
#!snakemake --use-conda --cores 8 --configfile test_data/test_oe//config_test.yaml

# %%
#Tb927.10.6480	Tb927_10_v5.1	1642783	1644328	+	1546	3112105	168	3042	2867	254

# %%
#now sample becouse file are too big for github

# %%
#samtools view -b -s 0.01 data/TbOE8166H/TbOE8166H.picard.bam   "Tb927_10_v5.1:1640000-1650000" > test_data/test_oe/test_region.bam

# %%
#samtools view -b -s 0.01 data/TbRIT-8166/TbRIT-8166.picard.bam "Tb927_08_v5.1:272330-285554"   > test_data/test_rit/test_region.bam

# %%
# !ls ../test_data/test_oe/
# Out:
# results  untitled.txt

# %%
# !samtools view -b -s 0.01 ../data/TbRIT-8166/TbRIT-8166.picard.bam "Tb927_08_v5.1:272330-285554" > ../test_data/test_oe/test_region.bam
# Out:
# /usr/bin/sh: 1: cannot create ../test_data/test_oe/test_region.bam: Directory nonexistent

# %%
ls -l ../test_data/test_oe/
# Out:
# total 0
# drwxr-xr-x 3 root root 96 Feb 16 12:49 results/

# %%
#snakemake --use-conda --cores 8 --configfile test_data/test_rit/config_test.yaml

# %%
#snakemake --use-conda --cores 8 --configfile test_data/test_oe/config_test.yaml
